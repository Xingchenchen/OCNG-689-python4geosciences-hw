# %% [markdown]
# # Homework 02
# ## Due Tuesday, February 2nd

# %% [markdown]
# ### 1. Make a dictionary
#
# Make a dictionary, d, whose keys and values are your name, hometown, department, student status (undergrad/grad), years at TAMU, and explanation of why you are taking this class.

# %%
d={'Name':'Xingchen Chen', 
   'Hometown':'China',
   'Department':'Geography',
   'Student Status':'Grad',
   'Years at TAMU':'since 2015', 
   'Explanation of Why Taking This Class':'always want to learn Python, see this class as an opportunity'}
print(d)
print('****************************')
print ('My name is '+d['Name'])
print('My hometown is in '+d['Hometown'])
print('I am in the '+d['Department']+' department')
print('I am a '+d['Student Status']+' student')
print('I have been in TAMU '+d['Years at TAMU'])
print('The reason I want to take this class is I '+d['Explanation of Why Taking This Class'])
# Out:
# {'Department': 'Geography', 'Hometown': 'China', 'Explanation of Why Taking This Class': 'always want to learn Python, see this class as an opportunity', 'Student Status': 'Grad', 'Name': 'Xingchen Chen', 'Years at TAMU': 'since 2015'}
# ****************************
# My name is Xingchen Chen
# My hometown is in China
# I am in the Geography department
# I am a Grad student
# I have been in TAMU since 2015
# The reason I want to take this class is I always want to learn Python, see this class as an opportunity

# %% [markdown]
# ### 2. Test for vowels
#
# Write a function that takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise. For example,
#     >>> isVowel("a")
#     True
#     >>> isVowel("b")
#     False
#
# You can compare the input character with a known list of vowels. Don't forget about case!

# %%
def isVowel(x):
    if x=='a':
        return 'True'
    elif x=='A':
        return 'True'
    elif x=='e':
        return 'True'
    elif x=='E':
        return 'True'
    elif x=='i':
        return 'True'
    elif x=='I':
        return 'True'
    elif x=='o':
        return 'True'
    elif x=='O':
        return 'True'
    elif x=='u':
        return 'True'
    elif x=='U':
        return 'True'
    else:
        return 'Flase'

print('A is vowel: '+isVowel('A'))
print('P is vowel: '+isVowel('P'))
isVowel('P')
# Out:
# A is vowel: True
# P is vowel: Flase
# 'Flase'

# %% [markdown]
# ### 3. Compute the length of a given list or string.
#
# Define a function that computes the length of a given list or string. (It is true that Python has the len() function built in, but do not use it for your solution — use a loop instead.)
#
# For example:
#     >>> length(['string1', 'string2'])
#     2
#     >>> length('string1')
#     7

# %%
def length(x):
    a = 0
    if type(x) is list:
        for item in x:              
            a += 1 
        return a
    if type(x) is str:
        for item in x:            
            a += 1 
        return a
    else:
        print('Neither a list or string')                             

print(length(['string1', 'string2']))
print(length('string1'))
# Out:
# 2
# 7

# %% [markdown]
# ### 4. Reverse a string
#
# Define a function reverse() that computes the reversal of a string. For example,
#     >>> reverse("I am testing")
#     "gnitset ma I"

# %%
def reverse(x):
    'This function reverse() computes the reversal of a string'
    a=[]
    b=len(x)-1
    for i in range(0,len(x)):
        a.append(x[b])
        b -= 1
    a= ''.join(a)    #join the list without space
    return a

reverse("I am testing")
# Out:
# 'gnitset ma I'

# %% [markdown]
# ### 5. Check for palindromes
#
# Define a function is_palindrome() that recognizes palindromes (i.e. words and phrases that look the same written forwards and backwards). Make sure that case and spaces are ignored in your function; for example,
#     >>> is_palindrome("Never odd or even")
#     True
#
# You can use your solution to #4 for solving this problem.

# %%
def is_palindrome(x):
    'This function is_palindrome(x) recognizes palindromes '
    a=0
    y=[]
    for i in range(0,len(x)):
        if x[a] == ' ':
            a += 1
            continue
        else:
            y.append(x[a])
            a += 1
    y=''.join(y)
    y=y.lower()
    b=reverse(y)
   
    if y==b:
        return(True)
    else:
        return(False)

is_palindrome("Never odd or even")
# Out:
# True

# %% [markdown]
# ### 6. Number lines in a text file
#
# Write a script (i.e., just code, no need to write a function) that numbers all of the lines in a text file, skipping empty lines, and writes the output to another specified file. The output file might look something like
#
#     1    This is the first line
#     2    This is the second line
#
#     3    This is the fourth line
#
# where the third line is empty, and not counted.

# %%
import math
f = open('GPS.dat')
d = open('output1.dat', 'w')
a=1
b = ['zeroth','first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'seventh',
     'eighth', 'ninth', 'tenth', 'eleventh', 'twelvth', 'thirteenth', 'fourteenth', 
     'fifteenth', 'sixteenth', 'seventeenth', 'eighteenth', 'nineteenth'];
c = ['twent', 'thirt', 'fourt', 'fift', 'sixt', 'sevent', 'eight', 'ninet'];
for line in f.readlines():
    data = line.split()
    if not data:
        d.write('\n')
        continue        
    if data:
        if (a < 20):
            d.write(str(a) + '  This is the '+ b[a] + ' line \n' )
            a +=1
        elif (a%10==0 and a>19 ):
            d.write(str(a) + '  This is the ' + c[math.floor(a/10)-2] + 'ieth line \n')
            a+=1
        else:
            d.write(str(a) + '  This is the ' + c[math.floor(a/10)-2] + 'y-' + b[a%10] + ' line \n')
            a+=1

# %% [markdown]
# ### 7. Convert list of words into list of integers of length of words
#
# Write a series of functions that maps a list of words into a list of integers representing the lengths of the correponding words. Write them in three different ways:
#
# 1. using a for-loop
#
# 2. using the higher order function map(), and
#
# 3. using list comprehensions.
#
# Do not use the len() function.
#
# For example,
#
#     >>> method1(['list', 'of', 'words'])
#     [4, 2, 5]

# %%
######################
####   METHOD 1  ####
#####################

def method1(x):
    'This function method1(x) uses for loop to count string length '
    a = 0
    b=[]
    c=0
    for string in x:
        y=string
        for item in y:
            a+=1
        b.append(a)
        c+=1
        a=0
    return b


######################
####   METHOD 2  ####
#####################

def count(x):
    a = 0
    for item in x:              
        a += 1 
    return a
    

def method2(y):    
    'This function method2(y) uses map() function to count string length '
    x= list( map(count, y))
    return x


######################
####   METHOD 3  ####
#####################    

def method3(x):
    'This function method3(x) uses list comprehension to count string length '
    a=[count(y) for y in x]
    return a

######################
####     TEST    ####
#####################   

            
method1(['list', 'of', 'words'])
method2(['list', 'of', 'words'])
method3(['list', 'of', 'words'])
# Out:
# [4, 2, 5]

# %% [markdown]
# ### 8. Encode and decode using ROT-13
#
# In cryptography, a Caesar cipher is a very simple encryption techniques in which each letter in the plain text is replaced by a letter some fixed number of positions down the alphabet. For example, with a shift of 3, A would be replaced by D, B would become E, and so on. The method is named after Julius Caesar, who used it to communicate with his generals. ROT-13 ("rotate by 13 places") is a widely used example of a Caesar cipher where the shift is 13. In Python, the key for ROT-13 may be represented by means of the following dictionary:
#
#     key = {'a':'n', 'b':'o', 'c':'p', 'd':'q', 'e':'r', 'f':'s', 'g':'t', 'h':'u',
#            'i':'v', 'j':'w', 'k':'x', 'l':'y', 'm':'z', 'n':'a', 'o':'b', 'p':'c',
#            'q':'d', 'r':'e', 's':'f', 't':'g', 'u':'h', 'v':'i', 'w':'j', 'x':'k',
#            'y':'l', 'z':'m', 'A':'N', 'B':'O', 'C':'P', 'D':'Q', 'E':'R', 'F':'S',
#            'G':'T', 'H':'U', 'I':'V', 'J':'W', 'K':'X', 'L':'Y', 'M':'Z', 'N':'A',
#            'O':'B', 'P':'C', 'Q':'D', 'R':'E', 'S':'F', 'T':'G', 'U':'H', 'V':'I',
#            'W':'J', 'X':'K', 'Y':'L', 'Z':'M'}
#
# Your task in this exercise is to implement an encoder/decoder of ROT-13. Once you're done, you will be able to read the following secret message:
#
#        Pnrfne pvcure? V zhpu cersre Pnrfne fnynq!
#
# Note that since English has 26 characters, your ROT-13 program will be able to both encode and decode texts written in English.

# %%
def ROT13(x):
    key = {'a':'n', 'b':'o', 'c':'p', 'd':'q', 'e':'r', 'f':'s', 'g':'t', 'h':'u', 
       'i':'v', 'j':'w', 'k':'x', 'l':'y', 'm':'z', 'n':'a', 'o':'b', 'p':'c', 
       'q':'d', 'r':'e', 's':'f', 't':'g', 'u':'h', 'v':'i', 'w':'j', 'x':'k',
       'y':'l', 'z':'m', 'A':'N', 'B':'O', 'C':'P', 'D':'Q', 'E':'R', 'F':'S', 
       'G':'T', 'H':'U', 'I':'V', 'J':'W', 'K':'X', 'L':'Y', 'M':'Z', 'N':'A', 
       'O':'B', 'P':'C', 'Q':'D', 'R':'E', 'S':'F', 'T':'G', 'U':'H', 'V':'I', 
       'W':'J', 'X':'K', 'Y':'L', 'Z':'M'}
    b=0
    c=[]
    
    for i in range(0,len(x)):
        if x[b] in key.values():
            c.append(key[x[b]])
            b += 1
        else:
            c.append(x[b])
            b += 1
    d=''.join(c)
    return d      

ROT13('Pnrfne pvcure? V zhpu cersre Pnrfne fnynq!')
# Out:
# 'Caesar cipher? I much prefer Caesar salad!'

# %% [markdown]
# ### 9. Fix the code
#
# "99 Bottles of Beer" is a traditional song in the United States and Canada. It is popular to sing on long trips, as it has a very repetitive format which is easy to memorize, and can take a long time to sing. The song's simple lyrics are as follows:
#
# 99 bottles of beer on the wall, 99 bottles of beer.
# Take one down, pass it around, 98 bottles of beer on the wall.
#
# The same verse is repeated, each time with one fewer bottle. The song is completed when the singer or singers reach zero.
#
# Code to generate all verses of this song has already been written and is provided below. However, it has several problems in it that prevent it from running properly. Your task is to fix the code, keeping a list of what you change, so that the code generates 3 verses of the song.

# %%
def words(num):
    """Returns words with proper number of beer bottles filled in."""
    
    if num != 1 :                # add a colon
        return( str(num) + ' bottles of beer on the wall, ' + str(num) + ' bottles of beer.\n' +  # add bracket for the return command 
            'Take one down, pass it around, ' + str(num-1) + ' bottles of beer on the wall.\n')

    elif num == 1:               # change '=' to '=='
        return( str(num) + ' bottle of beer on the wall, ' + str(num) + ' bottle of beer.\n' +    #add bracket for the return command
            'Take one down, pass it around, ' + str(num-1) + ' bottles of beer on the wall.\n')


numbottles = 3
        
for i in range(0,numbottles ):            #add a colon and edit the range function
    print(words(numbottles))               #indentation
    numbottles -=1                #numbottles should be less in each loop
# Out:
# 3 bottles of beer on the wall, 3 bottles of beer.
# Take one down, pass it around, 2 bottles of beer on the wall.
#
# 2 bottles of beer on the wall, 2 bottles of beer.
# Take one down, pass it around, 1 bottles of beer on the wall.
#
# 1 bottle of beer on the wall, 1 bottle of beer.
# Take one down, pass it around, 0 bottles of beer on the wall.

# %% [markdown]
# ### 10. Reading in and parsing a file
#
# Read in `data/GPS.dat`, a file containing GPS track information. This file is tab-delimited, but contains other characters as well. It has data from several drifters, whose names are listed in the file after the TRACK label; the first is named "ACTIVE LOG".
#
# Read in the date and time information from the file for the drifter ACTIVE LOG, and form a list of datetime objects with this information, where each line in the file is a data point that should have its own datetime object.
#
# *_Grad students:_* Separately, read in the locations and speed at all data points for each drifter. Create a dictionary with the name of each track as a key. The value of the dictionary will be another dictionary that has keys `latitude`, `longitude`, and `speed`.  That is, `gps['GANDALF']['speed']` will return a list containing a timeseries of the speed of that track.

# %%
f = open('GPS.dat')
lat1=[]
lon1=[]
speed1=[]
a=f.readlines()
for line in a[11:478]:
    data = line.split()
    if not data: continue
    if data[0] == 'Trackpoint':
        lat1.append(data[1]+' '+data[2])
        lon1.append(data[3]+' '+data[4])
        speed1.append(data[13]+' '+data[14])

lat2=[]
lon2=[]
for line in a[485:506]:
    data = line.split()
    if not data: continue
    if data[0] == 'Trackpoint':
        lat2.append(data[1]+' '+data[2])
        lon2.append(data[3]+' '+data[4])

lat3=[]
lon3=[]
for line in a[513:544]:
    data = line.split()
    if not data: continue
    if data[0] == 'Trackpoint':
        lat3.append(data[1]+' '+data[2])
        lon3.append(data[3]+' '+data[4])

lat4=[]
lon4=[]
for line in a[551:552]:
    data = line.split()
    if not data: continue
    if data[0] == 'Trackpoint':
        lat4.append(data[1]+' '+data[2])
        lon4.append(data[3]+' '+data[4])
        
lat5=[]
lon5=[]
for line in a[559:617]:
    data = line.split()
    if not data: continue
    if data[0] == 'Trackpoint':
        lat5.append(data[1]+' '+data[2])
        lon5.append(data[3]+' '+data[4])
d1={'latitude':lat1,'longitude':lon1,'speed':speed1}
d2={'latitude':lat2,'longitude':lon2}
d3={'latitude':lat3,'longitude':lon3}
d4={'latitude':lat4,'longitude':lon4}
d5={'latitude':lat5,'longitude':lon5}
gps={'ACTIVE LOG':d1,'LEGOLAS':d2, 'MERIADOC':d3, 'SAMWISE':d4, 'STRIDER':d5}
gps['ACTIVE LOG']['speed']
# Out:
# ['1.4 mph',
#  '1.7 mph',
#  '1.6 mph',
#  '2.9 mph',
#  '2.0 mph',
#  '1.6 mph',
#  '1.8 mph',
#  '2.7 mph',
#  '3.4 mph',
#  '3.7 mph',
#  '2.9 mph',
#  '3.4 mph',
#  '4.7 mph',
#  '4.4 mph',
#  '4.3 mph',
#  '4.3 mph',
#  '4.9 mph',
#  '4.8 mph',
#  '4.8 mph',
#  '5.2 mph',
#  '5.2 mph',
#  '4.8 mph',
#  '4.9 mph',
#  '5.0 mph',
#  '4.7 mph',
#  '4.9 mph',
#  '4.7 mph',
#  '5.0 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.5 mph',
#  '4.3 mph',
#  '4.9 mph',
#  '4.6 mph',
#  '4.7 mph',
#  '4.4 mph',
#  '4.5 mph',
#  '4.9 mph',
#  '4.7 mph',
#  '4.2 mph',
#  '4.6 mph',
#  '4.7 mph',
#  '4.5 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.5 mph',
#  '4.4 mph',
#  '4.4 mph',
#  '4.8 mph',
#  '4.4 mph',
#  '4.7 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.7 mph',
#  '4.4 mph',
#  '4.4 mph',
#  '4.6 mph',
#  '4.5 mph',
#  '4.6 mph',
#  '4.9 mph',
#  '4.4 mph',
#  '4.4 mph',
#  '4.4 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.6 mph',
#  '4.5 mph',
#  '4.6 mph',
#  '4.7 mph',
#  '4.0 mph',
#  '4.3 mph',
#  '4.4 mph',
#  '4.8 mph',
#  '4.9 mph',
#  '4.2 mph',
#  '4.5 mph',
#  '4.6 mph',
#  '4.4 mph',
#  '4.9 mph',
#  '4.7 mph',
#  '4.5 mph',
#  '4.7 mph',
#  '4.4 mph',
#  '5.0 mph',
#  '5.2 mph',
#  '5.0 mph',
#  '5.2 mph',
#  '4.7 mph',
#  '5.3 mph',
#  '5.2 mph',
#  '5.1 mph',
#  '5.1 mph',
#  '4.7 mph',
#  '5.0 mph',
#  '4.4 mph',
#  '4.5 mph',
#  '4.3 mph',
#  '4.5 mph',
#  '4.8 mph',
#  '4.2 mph',
#  '4.4 mph',
#  '4.5 mph',
#  '4.4 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '5.1 mph',
#  '4.4 mph',
#  '4.7 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.7 mph',
#  '4.3 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.7 mph',
#  '4.7 mph',
#  '4.8 mph',
#  '4.5 mph',
#  '4.9 mph',
#  '4.5 mph',
#  '4.5 mph',
#  '4.6 mph',
#  '4.6 mph',
#  '4.2 mph',
#  '4.3 mph',
#  '4.6 mph',
#  '3.9 mph',
#  '1.8 mph',
#  '1.4 mph',
#  '2.9 mph',
#  '2.7 mph',
#  '3.4 mph',
#  '4.4 mph',
#  '4.4 mph',
#  '2.6 mph',
#  '1.9 mph',
#  '2.8 mph',
#  '2.1 mph',
#  '1.4 mph',
#  '2.3 mph',
#  '1.3 mph',
#  '0.86 mph',
#  '0.86 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.8 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.3 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.3 mph',
#  '1.6 mph',
#  '1.3 mph',
#  '1.3 mph',
#  '1.0 mph',
#  '1.6 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.3 mph',
#  '1.3 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.3 mph',
#  '1.6 mph',
#  '1.3 mph',
#  '1.5 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '3.0 mph',
#  '3.1 mph',
#  '3.1 mph',
#  '3.9 mph',
#  '4.8 mph',
#  '4.9 mph',
#  '4.8 mph',
#  '4.8 mph',
#  '4.8 mph',
#  '5.1 mph',
#  '4.9 mph',
#  '4.5 mph',
#  '4.2 mph',
#  '3.0 mph',
#  '2.2 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.9 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.9 mph',
#  '1.5 mph',
#  '1.9 mph',
#  '1.7 mph',
#  '1.6 mph',
#  '1.9 mph',
#  '1.7 mph',
#  '1.9 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.7 mph',
#  '1.3 mph',
#  '1.9 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.8 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.7 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.9 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.7 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.7 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.7 mph',
#  '1.9 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.6 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.0 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.3 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.0 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.5 mph',
#  '1.4 mph',
#  '1.1 mph',
#  '1.1 mph',
#  '1.4 mph',
#  '1.3 mph',
#  '1.1 mph',
#  '1.6 mph',
#  '2.4 mph',
#  '2.8 mph',
#  '2.5 mph',
#  '1.9 mph',
#  '2.4 mph',
#  '3.9 mph',
#  '4.7 mph',
#  '5.0 mph',
#  '4.8 mph',
#  '5.1 mph',
#  '4.8 mph',
#  '4.7 mph',
#  '5.0 mph',
#  '5.0 mph',
#  '5.0 mph',
#  '6.6 mph']

# %% [markdown]
# ### 11. (Grad) Constructing terms in a Taylor series to approximate a function
#
# The Taylor series expansion for the sine function is given by
# $$ \text{sin}(x) = \Sigma^\infty_{k=0} \frac{(-1)^k x^{1+2k}}{(1+2k)!}$$
#
# This expression gives an exact form for sin(x) when an infinite number of terms are used; any truncation gives an approximation. Write a loop that constructs terms from $k=0$ up to $k=N$. Don't use any function for the factorial since we haven't gotten to NumPy... create it yourself, instead. Provide the value of sin(0.5) with N=5 terms. How many terms do you need to include before the answer starts to plateau?

# %%
def Taylor1(x, k):
    a=pow(-1,k)*pow(x,1+2*k)
    b=(1+2*k)
    c=(1+2*k)
    for i in range(0,2*k):
        if b>0:
            c=c*(b-1)
            b-=1
        else:
            break
    d=a/c
    return d

def Taylor(x, N):
    e=0
    for i in range(0,N+1):
        e += Taylor1(x,i)
        i += 1
    return e

Taylor(0.5,50)

        
# about 8 terms before the answer atarts to plateau
# Out:
# 0.479425538604203
